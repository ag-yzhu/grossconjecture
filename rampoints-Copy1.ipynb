# %%
B = load("largeramlist.sobj");
N = load("vanishingcase1.sobj")
[b3,b4,b5,b6,b7,b8,b9] = B[0];
print(b3[0] in N, b3[1] in N, b3[2] in N, b3[3] in N);
print(b4[0] in N, b4[1] in N, b4[2] in N, b4[3] in N);
print(b5[0] in N, b5[1] in N, b5[2] in N, b5[3] in N);
print(b6[0] in N, b6[1] in N, b6[2] in N, b6[3] in N);
print(b7[0] in N, b7[1] in N, b7[2] in N, b7[3] in N);
print(b8[0] in N, b8[1] in N, b8[2] in N, b8[3] in N);
print(b9[0] in N, b9[1] in N, b9[2] in N, b9[3] in N);

from riemann_theta.riemann_theta import RiemannTheta
prec = 1330;
CC = ComplexField(1330);

tau = Matrix(CC, 4, 4, [[-8....-414 +1....*I,-3....-414 -4....-414*I,-1....-413 -7....-414*I,1....-413 -7....-414*I], [-3....-414 -4....-414*I,4....-414 +0....*I,4....-414 -3....-414*I,-1....-415 +7....-414*I], [-1....-413 -7....-414*I,4....-414 -3....-414*I,8....-414 +0....*I,6....-414 +1....-413*I], [1....-413 -7....-414*I,-1....-415 +7....-414*I,6....-414 +1....-413*I,-2....-413 +0....*I]])

RT=RiemannTheta(tau);

print("ramifying point info")
a3 = ((RT(char = b3[0])*RT(char = b3[1]))/(RT(char = b3[2])*RT(char = b3[3])))^2;
print(a3);

      
#if a3 <= 10^300:
    #f3 = gp.algdep(a3, 200);
    #print(f3);
#else:
    #print("a3 is too big");
#print(factor(f3))

print("ramifying point info")
a4 = ((RT(char = b4[0])*RT(char = b4[1]))/(RT(char = b4[2])*RT(char = b4[3])))^2;
print(a4)


#if a4 <= 10^300:
#    f4 = gp.algdep(a4, 200);
#    print(f4);
#else:
#    print("a4 is too big");
#print(factor(f4))

print("ramifying point info")
a5 = ((RT(char = b5[0])*RT(char = b5[1]))/(RT(char = b5[2])*RT(char = b5[3])))^2;
print(a5)

#if a5 <= 10^300:
#    f5 = gp.algdep(a5, 200);
#    print(f5);
#else:
#    print("a5 is too big");
#print(factor(f5))

print("ramifying point info")
a6 = ((RT(char = b6[0])*RT(char = b6[1]))/(RT(char = b6[2])*RT(char = b6[3])))^2;
print(a6)


#if a6 <= 10^300:
#    f6 = gp.algdep(a6, 200);
#    print(f6);
#else:
#    print("a6 is too big");
#print(factor(f6))

print("ramifying point info")
a7 = ((RT(char = b7[0])*RT(char = b7[1]))/(RT(char = b7[2])*RT(char = b7[3])))^2;
print(a7)


#if a7 <= 10^300:
#    f7 = gp.algdep(a7, 200);
#    print(f7);
#else:
#    print("a7 is too big");
#print(factor(f7))

print("ramifying point info")
a8 = ((RT(char = b8[0])*RT(char = b8[1]))/(RT(char = b8[2])*RT(char = b8[3])))^2;
print(a8)



#if a8 <= 10^300:
#    f8 = gp.algdep(a8, 200);
#    print(f8);
#else:
#    print("a8 is too big");
#print(factor(f8))

print("ramifying point info")
a9 = ((RT(char = b9[0])*RT(char = b9[1]))/(RT(char = b9[2])*RT(char = b9[3])))^2;
print(a9)

#if a9 <= 10^300:
#    f9 = gp.algdep(a9, 200);
#    print(f9);
#else:
#    print("a9 is too big");
#print(factor(f9))

#see if the candidate gives right equation
CCC = ComplexField(4000);
a0 = CCC((a3 + a4 + a5 + a6 + a7 + a8 + a9 + 1)/8);
R = CCC[x];
f = (x-1+a0)*(x-CCC(a3)+a0)*(x-CCC(a4)+a0)*(x-CCC(a5)+a0)*(x-CCC(a6)+a0)*(x-CCC(a7)+a0)*(x-CCC(a8)+a0)*(x-CCC(a9)+a0);
f.coefficients(sparse=False)
# Out:
# [-1.... + 2....-387*I,
#  -8.... + 1....-387*I,
#  -1.... + 1....-388*I,
#  -1.... + 1....-389*I,
#  -1.... + 7....-391*I,
#  -391314.... + 2....-392*I,
#  -6451.... + 2....-394*I,
#  3....-399 + 4....-798*I,
#  1]
